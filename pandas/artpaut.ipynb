# %% [markdown]
# # Indicadores Instituto de Física

# %% [markdown]
# Código de tabla de contenidos en la próxima celda invisible

# %% [markdown]
# <style>
#   #menu {
#     position: fixed;
#     right: 0;
#     top: 50%;
#     width: 15em;
#     margin: -2.5em 0 0 0;
#     z-index: 5;
#     background: hsla(80, 90%, 40%, 0.7);
#     color: white;
#     font: Georgia, "Times New Roman", Times, serif;
#     font-weight: normal;
#     font-size: 100%;
#     text-align: left;
#     border: solid hsla(80, 90%, 40%, 0.5);
#     border-right: none;
#     padding: 0.5em 0.5em 0.5em 2.5em;
#     box-shadow: 0 1px 3px black;
#     border-radius: 3em 0.5em 0.5em 3em;
#   }
#   #menu li { margin: 0 }
#   #menu a { color: inherit }
#
#   /* Make menu absolute, not fixed, on IE 5 & 6 */
#   #menu { position: absolute }
#   *>#menu { position: fixed }
# </style>
#
# <ol id=menu>
#     <li><a href="#Estudiantes" target="">Estudiantes</a></li>
#     <li><a href="#Proyectos_vigentes" target="">Proyectos vigentes</a></li>
#     <li><a href="#Articulos" target="">Artículos</a></li>
# </ol>

# %% [markdown]
# ### Función de búsqueda

# %% [markdown]
# Para obtener las claves de las hojas de cálculo de Google, visita la [página de búsqueda de Indicadores](http://gfif.udea.edu.co/gssis/sql_query/search.html): (Seleccione indicador, ponga `*` en la caja de `"select"`, pulse el botón de búsqueda y abra el link HTML).

# %%
import pandas as pd
def read_google_cvs(gss_url="http://spreadsheets.google.com",\
    gss_format="csv",\
    gss_key="0AuLa_xuSIEvxdERYSGVQWDBTX1NCN19QMXVpb0lhWXc",\
    gss_sheet=0,\
    gss_query="select B,D,E,F,I where (H contains 'GFIF') order by D desc",\
    gss_keep_default_na=False
    ):
    import urllib
    import pandas as pd
    """
    read a google spreadsheet in cvs format and return a pandas DataFrame object.
       ....
       gss_keep_default_na: (False) Blank values are filled with NaN
    """
    issn_url="%s/tq?tqx=out:%s&tq=%s&key=%s&gid=%s" %(gss_url,\
                                           gss_format,\
                                           gss_query,\
                                           gss_key,\
                                           str(gss_sheet))

    gfile=urllib.urlopen(issn_url)
    return pd.read_csv(gfile,keep_default_na=gss_keep_default_na)

def catutf8(fileutf8):
    """
    Print UTF-8 file.
    """
    fo=open(fileutf8,'r')
    a=fo.read()
    a=a.decode('utf8')
    fo.close()
    print a

#Sample of default search
df=read_google_cvs()
df
# Out:
#                          ESTUDIANTE  Fecha de ingreso   Fecha de graduación   \
# 0               Dilia Maria Portillo              2008                  2013
# 1     Camilo Andrés Salazar González              null                  2013
# 2                    Robinson Longas              null                  2011
# 3                   John David Gómez              null                  2011
# 4                    Jose David Ruíz              null                  2010
# 5                 Juan Alberto Yepes              null                  2008
# 6  Walter Orlando Tangarife García\n              null                  2008
#
#     Estado          ASESOR
# 0  Graduado  Diego Restrepo
# 1  Graduado  Diego Restrepo
# 2  Graduado  Diego Restrepo
# 3  Graduado   William Ponce
# 4  Graduado  Diego Restrepo
# 5  Graduado  Diego Restrepo
# 6  Graduado  Diego Restrepo

# %% [markdown]
# Make dir for output files

# %%
# %%bash
# if [ ! -d indicadores ];then
#   mkdir indicadores
# fi

# %%
cd indicadores
# Out:
# /home/restrepo/prog/google_apps_accounts/gssis/pandas/indicadores

# %% [markdown]
# <h2 id="Estudiantes">Estudiantes</h2>

# %% [markdown]
# ### Ejemplo salida $\LaTeX$

# %% [markdown]
# #### Estudiantes graduados de doctorado de GFIF:

# %% [markdown]
# ##### Obtener cvs filtrado con el query de google scholar:

# %%
dff=read_google_cvs(gss_key='0AuLa_xuSIEvxdERYSGVQWDBTX1NCN19QMXVpb0lhWXc',\
                   gss_sheet=2,\
                   gss_query="select+B,E,I,U+where+(H+contains+'GFIF'+and+F+contains+'Graduado')+order+by+D+desc")
dff
# Out:
#                         ESTUDIANTE Fecha de graduación  \
# 0         Mauricio Velásquez López              2013-1
# 1    Richard H. Benavides Palacios              2011-2
# 2           Yithsbey Giraldo Usuga              2009-2
# 3          Luis A. Muñoz Hernández              2010-2
# 4              Oscar Zapata Noreña              2010-2
# 5         Diego A. Gutierrez Isaza              2009-1
# 6  José Patricio Valencia Valencia              2006-2
# 7      Jorge Ivan Zuluaga Callejas              2004-2
# 8       Luis Alberto Sanchez Duque              2002-2
# 9        Jesús María Mira Martínez              2000-2
#
#                             ASESOR         Estado Laboral
# 0                Diego Restrepo Q.
# 1                 William Ponce G.                    ITM
# 2                    William Ponce  Universidad de Nariño
# 3                     Enrico Nardi                    ITM
# 4                   Diego Restrepo                   UdeA
# 5                    William Ponce                    ITM
# 6                      Huachuan Wu                   UdeA
# 7                     Enrico Nardi                   UdeA
# 8  William Ponce- Daniel Jaramillo     UNAL sede Medellìn
# 9                     Enrico Nardi                   UdeA

# %% [markdown]
# ##### Or: Obtener cvs completo, mirar sus columnas y hacer el `query` con pandas

# %%
df=read_google_cvs(gss_key='0AuLa_xuSIEvxdERYSGVQWDBTX1NCN19QMXVpb0lhWXc',\
                   gss_sheet=2,\
                   gss_query="select *")
df.columns
# Out:
# Index([No.TESIS, ESTUDIANTE, Cédula, Fecha de ingreso, Fecha de graduación, Estado, INSTITUTO, GRUPO, ASESOR, CORREO, NOMBRE TESIS, Fecha de sustentación, UBICACIÓN ESTANTE, SIGNATURA, Distinción, Becado de, Situación, Proyecto, Pasantía, Doble titulación, Estado Laboral], dtype=object)

# %%
dff=df[pd.np.logical_and(df['GRUPO'].str.contains('GFIF'),df['Estado']=='Graduado')]
dff=dff[['ESTUDIANTE','Fecha de graduación','ASESOR','Estado Laboral']]
dff.reset_index(drop=True)
# Out:
#                         ESTUDIANTE Fecha de graduación  \
# 0         Mauricio Velásquez López              2013-1
# 1    Richard H. Benavides Palacios              2011-2
# 2          Luis A. Muñoz Hernández              2010-2
# 3              Oscar Zapata Noreña              2010-2
# 4           Yithsbey Giraldo Usuga              2009-2
# 5         Diego A. Gutierrez Isaza              2009-1
# 6  José Patricio Valencia Valencia              2006-2
# 7      Jorge Ivan Zuluaga Callejas              2004-2
# 8       Luis Alberto Sanchez Duque              2002-2
# 9        Jesús María Mira Martínez              2000-2
#
#                             ASESOR         Estado Laboral
# 0                Diego Restrepo Q.
# 1                 William Ponce G.                    ITM
# 2                     Enrico Nardi                    ITM
# 3                   Diego Restrepo                   UdeA
# 4                    William Ponce  Universidad de Nariño
# 5                    William Ponce                    ITM
# 6                      Huachuan Wu                   UdeA
# 7                     Enrico Nardi                   UdeA
# 8  William Ponce- Daniel Jaramillo     UNAL sede Medellìn
# 9                     Enrico Nardi                   UdeA

# %% [markdown]
# See [Compile a LaTeX document into a png image](http://tex.stackexchange.com/questions/11866/compile-a-latex-document-into-a-png-image-thats-as-short-as-possible):

# %%
f=open('doctorado.tex','w')
#f.write(r'\documentclass[convert]{standalone}')
f.write(r'''\documentclass[convert={size=800x600}]{standalone}
\usepackage[utf8]{inputenc}
\begin{document}
''')
s=dff.to_latex(index=False)
f.write(s.encode("utf"))
f.write(r'\end{document}')
f.close()

# %%
# %%bash
# pdflatex -shell-escape doctorado.tex > /dev/null

# %%
from IPython.display import Image
Image(filename='doctorado.png')

# %%
catutf8('doctorado.tex')
# Out:
# \documentclass[convert={size=800x600}]{standalone}
# \usepackage[utf8]{inputenc}
# \begin{document}
# \begin{tabular}{|l|c|c|c|c|}
# \hline
#                       ESTUDIANTE & Fecha de graduación &                           ASESOR &         Estado Laboral \\
# \hline
#         Mauricio Velásquez López &              2013-1 &                Diego Restrepo Q. &                        \\
#    Richard H. Benavides Palacios &              2011-2 &                 William Ponce G. &                    ITM \\
#          Luis A. Muñoz Hernández &              2010-2 &                     Enrico Nardi &                    ITM \\
#              Oscar Zapata Noreña &              2010-2 &                   Diego Restrepo &                   UdeA \\
#           Yithsbey Giraldo Usuga &              2009-2 &                    William Ponce &  Universidad de Nariño \\
#         Diego A. Gutierrez Isaza &              2009-1 &                    William Ponce &                    ITM \\
#  José Patricio Valencia Valencia &              2006-2 &                      Huachuan Wu &                   UdeA \\
#      Jorge Ivan Zuluaga Callejas &              2004-2 &                     Enrico Nardi &                   UdeA \\
#       Luis Alberto Sanchez Duque &              2002-2 &  William Ponce- Daniel Jaramillo &     UNAL sede Medellìn \\
#        Jesús María Mira Martínez &              2000-2 &                     Enrico Nardi &                   UdeA \\
# \hline
# \end{tabular}
# \end{document}

# %% [markdown]
# ### Estudiantes Graduados Doctorado en Física por Grupos

# %%
dft=df[df['Estado']=='Graduado']
dft['GRUPO'].value_counts().plot(kind='barh', rot=0)
#plt.savefig('doc.pdf')

# %% [markdown]
# <h2 id="Proyectos_vigentes">Proyectos vigentes</h2>

# %% [markdown]
# A continuación obtendremos una lista en $\LaTeX$ con los proyectos vigentes del Grupo GFIF

# %%
df=read_google_cvs(gss_key='0AjqGPI5Q_Ez6dFE1S2pWQkZJdFkycWFvNXdaMDhkWFE',gss_query="select *")
df.columns
# Out:
# Index([Timestamp, Username, Proyecto ID, Título, Investigador Principal, Acta, Fecha de Inicio, Fecha de Finalización, Tipo, Centro, Grupo, Valor Total, Recursos Frescos, Unnamed: 13], dtype=object)

# %% [markdown]
# Adicione una nueva columna al DataFrame de pandas filtrado con los proyectos de `'GFIF'`, con el año obtenido a partir de la `'Fecha de Finalización'`

# %%
df=df[df['Grupo'].str.contains('GFIF')]
df=df.reset_index(drop=True)
year=[]
for i in range(df.shape[0]):
  year.append(int(df['Fecha de Finalización'][i].split('-')[0]))
    
df['Año de Finalización']=year

# %%
import datetime
dff=df[df['Año de Finalización']>=datetime.datetime.now().year]
dff=dff.sort(['Fecha de Inicio'],ascending=False)
dff=dff.reset_index(drop=True)
dff[['Investigador Principal','Fecha de Inicio','Tipo']]
# Out:
#               Investigador Principal Fecha de Inicio  \
# 0                      William Ponce      2014-01-01
# 1        Óscar Alberto Zapata Noreña      2014-01-01
# 2                     Diego Restrepo      2013-03-06
# 3                     Diego Restrepo      2013-02-14
# 4        Óscar Alberto Zapata Noreña      2012-11-09
# 5                Antonio Enea Romano      2012-01-26
# 6  Diego Alejandro Restrepo Quintero      2012-01-01
#
#                             Tipo
# 0  Convocatoria Ciencias Exactas
# 1  Convocatoria Ciencias Exactas
# 2                 Sostenibilidad
# 3                    Colciencias
# 4   Profesores Recién Vinculados
# 5   Profesores Recién Vinculados
# 6                Mediana Cuantía

# %% [markdown]
# Prepare $\LaTeX$ output

# %%
f=open('proyectos.tex','w')
f.write(r'''\documentclass{article}
\usepackage[utf8]{inputenc}
\pagestyle{empty}
\begin{document}
\begin{itemize}
''')
for i in range(dff.shape[0]):
     f.write(r'''\item %s
\begin{itemize}
\item Investigador principal: %s
\item Fecha de inicio y tipo: %s, %s
\end{itemize}
''' %(dff['Título'][i],\
      dff['Investigador Principal'][i],\
      dff['Fecha de Inicio'][i].split('-')[0],\
      dff['Tipo'][i])
     ) 

f.write(r'''\end{itemize}
\end{document}
''')
f.close()

# %%
# %%bash
# pdflatex -shell-escape proyectos.tex >/dev/null
# pdfcrop proyectos.pdf proyectos.pdf  >/dev/null
# convert -resize 559x749 -density 300 proyectos.pdf proyectos.png

# %% [markdown]
# Open file generated without `-resize` in a new tab to get default size. The resize:

# %%
1.7*pd.np.asarray([329,441])
# Out:
# array([ 559.3,  749.7])

# %%
from IPython.display import Image
Image(filename='proyectos.png')

# %%
catutf8('proyectos.tex')
# Out:
# \documentclass{article}
# \usepackage[utf8]{inputenc}
# \pagestyle{empty}
# \begin{document}
# \begin{itemize}
# \item Masas y mezclas de neutrinos en modelos 3-N-1 (N=3,4)
# \begin{itemize}
# \item Investigador principal: William Ponce
# \item Fecha de inicio y tipo: 2014, Convocatoria Ciencias Exactas
# \end{itemize}
# \item Implicaciones de modelos tipo seesaw radiativo en las fronteras de la física de partículas y la cosmología
# \begin{itemize}
# \item Investigador principal: Óscar Alberto Zapata Noreña
# \item Fecha de inicio y tipo: 2014, Convocatoria Ciencias Exactas
# \end{itemize}
# \item Estrategia para la Sostenibilidad GFIF 2013-2014
# \begin{itemize}
# \item Investigador principal: Diego Restrepo
# \item Fecha de inicio y tipo: 2013, Sostenibilidad
# \end{itemize}
# \item Implicaciones de modelos supersimétricos con violación de paridad R en las fronteras de física de partículas y cosmología
# \begin{itemize}
# \item Investigador principal: Diego Restrepo
# \item Fecha de inicio y tipo: 2013, Colciencias
# \end{itemize}
# \item Materia oscura de gravitinos y masas de neutrinos en modelos con violación trilineal y bilineal inducida de paridad R
# \begin{itemize}
# \item Investigador principal: Óscar Alberto Zapata Noreña
# \item Fecha de inicio y tipo: 2012, Profesores Recién Vinculados
# \end{itemize}
# \item Testing the Standar Cosmological Model Studyng the effects of not gaussianity and large scale inhomogenities
# \begin{itemize}
# \item Investigador principal: Antonio Enea Romano
# \item Fecha de inicio y tipo: 2012, Profesores Recién Vinculados
# \end{itemize}
# \item Fenomenología de modelos supersimétricos con ruptura de paridad R y violación de número leptónico.
# \begin{itemize}
# \item Investigador principal: Diego Alejandro Restrepo Quintero
# \item Fecha de inicio y tipo: 2012, Mediana Cuantía
# \end{itemize}
# \end{itemize}
# \end{document}

# %% [markdown]
# <h2 id="Articulos">Artículos</h2>

# %% [markdown]
# ### Por Grupo

# %%
df=read_google_cvs(gss_key='0AjqGPI5Q_Ez6dDA3ajhtYVVDOWdBckVhWm1MSFRET1E',gss_query="select *")
df.columns
# Out:
# Index([Marca temporal, Nombre de usuario, Año, Tipo, Autor(es), Revista, Vol., pág., ISSN, Artículo, Impreso, PDF, Grupo, DOI, Tipo.1, Rótulo, Autores de la UdeA, Clasificación Colciencias, Está (S,N,NP)], dtype=object)

# %%
publicadas=df[df['ISSN']!='0000-0000']
publicadas=publicadas.reset_index(drop=True)
publicadas=publicadas.replace('','Desconocido')
#Convierta Anyo a entero
for i in range(publicadas.shape[0]):
    if publicadas['Año'][i]!='null':
        publicadas['Año'][i]=int(publicadas['Año'][i])

publicadas[:4]
# Out:
#   Marca temporal Nombre de usuario   Año           Tipo  \
# 0    Desconocido       Desconocido  1980  Internacional
# 1    Desconocido       Desconocido  2003  Internacional
# 2    Desconocido       Desconocido  2002  Internacional
# 3    Desconocido       Desconocido  2001  Internacional
#
#                                            Autor(es)  \
# 0  Donoghue, John F; Golowich, Eugene; Ponce, Wil...
# 1  Ponce, William A; Giraldo, Yithsbey; Sánchez, ...
# 2  Ponce, William A; Florez, Juan B; Sanchez, Lui...
# 3   Sánchez, Luis A; Ponce, William A; Martinez, R;
#
#                                      Revista Vol.     pág.       ISSN  \
# 0                          Physical Review D   21      186  1550-7998
# 1                          Physical Review D   67    75001  1550-7998
# 2  International Journal of Modern Physics A   17  643-659  0217-751X
# 3                          Physical Review D   64    75013  1550-7998
#
#                                             Artículo      Impreso          PDF  \
# 0  Analysis of ΔS= 1 nonleptonic weak decays and ...  Desconocido  Desconocido
# 1  Minimal scalar sector of 3-3-1 models without ...  Desconocido  Desconocido
# 2  Analysis of SU (3) c⊗ SU (3) L⊗ U (1) X local ...  Desconocido  Desconocido
# 3  SU (3) _ {c}⊗ SU (3) _ {L}⊗ U (1) _ {X} as an ...  Desconocido  Desconocido
#
#                                                Grupo          DOI       Tipo.1  \
# 0  GFIF: Grupo de Fenomenología de Interacciones ...  Desconocido  Desconocido
# 1  GFIF: Grupo de Fenomenología de Interacciones ...  Desconocido  Desconocido
# 2  GFIF: Grupo de Fenomenología de Interacciones ...  Desconocido  Desconocido
# 3  GFIF: Grupo de Fenomenología de Interacciones ...  Desconocido  Desconocido
#
#         Rótulo               Autores de la UdeA Clasificación Colciencias  \
# 0  Desconocido  Ponce Gutiérrez William Alberto                        A1
# 1  Desconocido  Ponce Gutiérrez William Alberto                        A1
# 2  Desconocido  Ponce Gutiérrez William Alberto                        A1
# 3  Desconocido  Ponce Gutiérrez William Alberto                        A1
#
#   Está (S,N,NP)
# 0   Desconocido
# 1   Desconocido
# 2   Desconocido
# 3   Desconocido

# %% [markdown]
# #### Todos los años

# %%
publicadas['Grupo'].value_counts()[:10].plot(kind='barh', rot=0)

# %% [markdown]
# #### Últimos cinco años

# %%
import datetime
publicadas5=publicadas[publicadas['Año']>datetime.datetime.now().year-5]
publicadas5['Grupo'].value_counts()[:10].plot(kind='barh', rot=0)

# %% [markdown]
# Internacionales y Nacionales

# %% [markdown]
# The group counts, analogous to the value_counts function above, can be computed
#     using size. This result is then reshaped into a table with unstack:

# %%
tipo5 = np.where(publicadas5['Tipo'].str.contains('Internacional'),'Internacional', 'Nacional')
by_group_tipo5 = publicadas5.groupby(['Grupo', tipo5])
gt_counts = by_group_tipo5.size().unstack().fillna(0)
indexer = gt_counts.sum(1).argsort()
count_subset = gt_counts.take(indexer)
count_subset[4:].plot(kind='barh', stacked=True)

# %% [markdown]
# ### Clasificación Colciencias

# %%
total=publicadas['Clasificación Colciencias'].value_counts()
print "Total A1+A2: ",total['A1']+total['A2']
# Out:
# Total A1+A2:  637

# %%
publicadas['Clasificación Colciencias'].value_counts().plot(kind='barh')

# %% [markdown]
# #### Últimos cinco  años

# %%
total=publicadas5['Clasificación Colciencias'].value_counts()
print "Total A1+A2: ",total['A1']+total['A2']
# Out:
# Total A1+A2:  271

# %%
publicadas5['Clasificación Colciencias'].value_counts().plot(kind='barh')

# %% [markdown]
# #### Publicadas último año

# %%
import datetime
publicadas1=publicadas[publicadas['Año']>datetime.datetime.now().year-1]
len(publicadas1)
# Out:
# 54
